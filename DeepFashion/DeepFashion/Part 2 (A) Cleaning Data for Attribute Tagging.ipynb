# %%
import os
import tqdm as tqdm

# %%
from PIL import Image
import numpy as np
import time
import pandas as pd
import tqdm

pwd = os.getcwd()
category = '/Category and Attribute Prediction Benchmark/'
directory = pwd + category
pd.options.mode.chained_assignment = None  # default='warn'

# %%
data_path = directory + 'Img/'
bbox_path = directory + 'Anno/list_bbox.txt'
attr_path = directory + 'Anno/list_attr_img.txt'
attr_path2 = directory + 'Anno/list_attr_img2.txt'
attr_type_path = directory + 'Anno/list_attr_cloth.txt'
img_category_path = directory + 'Anno/list_category_img.txt'
img_category_path2 = directory + 'Anno/list_category_img2.txt'

img_category = {}
img_attr = {}
img_bbox = {}
attr_type = {}
attr_frequency = [0 for i in range(1000)]
train_data = []
test_data = []
val_data = []

# %%
bbox_path
# Out:
# '/root/DeepFashion/DeepFashion/Category and Attribute Prediction Benchmark/Anno/list_bbox.txt'

# %%
#read image,cut the clothes area of the image,resize to 100*100 and return an array
def read_img(path):
    try:
        img = Image.open(path)
        img = img.crop(img_bbox[path])
        img = img.resize((100,100))
        img.show()
        i_array = np.array(img)
        return i_array
    except Exception:
        print "read_img Error!"
        
'''''
r = read_img(r'./img_00000002.jpg')[:,:,2]
a = Image.fromarray(r)
a.save(r'./img_00000002_2.png')
'''''
# Out:
# "''\nr = read_img(r'./img_00000002.jpg')[:,:,2]\na = Image.fromarray(r)\na.save(r'./img_00000002_2.png')\n"

# %%
#read list_bbox,save as a dict
def read_bbox():
    try:
        bbox_file = open(bbox_path, 'r')
    except Exception:
        print "list_bbox.txt IOError!"
    bbox_data = bbox_file.readlines()
    for d, i in zip(bbox_data[2:],range(bbox_data.__len__()-2)):
        s = d.split()
        p = data_path + s[0]
        bbox_loca = []
        for a in s[1:]:
            bbox_loca.append(float(a))
        img_bbox[p] = bbox_loca
    bbox_file.close()
    print 'list_bbox.txt ready!'

# %%
def get_attr_type():
    attr_type_file = open(attr_type_path, 'r')
    lines = attr_type_file.readlines()
    for i in lines[2:]:
        s = i.split()
        attr = s[:-1]
        attr = ' '.join(attr)
        attr_num = s[-1]
        attr_type[attr] = attr_num
    print 'list_attr_cloth.txt ready!'

# %%
get_attr_type()
attr_type
# Out:
# list_attr_cloth.txt ready!
# {'gingham': '2',
#  'crochet knit': '2',
#  'lace': '2',
#  'knotted': '4',
#  'embroidered lace': '2',
#  'sleek': '2',
#  'toggle': '4',
#  'classic': '5',
#  'dainty': '5',
#  'racerback': '4',
#  'lacy': '2',
#  'mandala': '1',
#  'slouchy': '3',
#  'venice': '5',
#  'pj': '5',
#  'ditsy floral': '1',
#  'paris': '5',
#  'burnout': '2',
#  'crochet maxi': '3',
#  'sparkling': '2',
#  'mineral wash': '2',
#  'patched': '2',
#  'bike': '5',
#  'scoop-neck': '4',
#  'gauze peasant': '3',
#  'smile': '5',
#  'tweed': '2',
#  'ruffle trim': '4',
#  'twist-front': '4',
#  'embroidered shift': '3',
#  'garden': '5',
#  'nautical striped': '1',
#  'internet': '5',
#  'kitty': '5',
#  'zip-pocket': '4',
#  'wave': '5',
#  'cami crop': '3',
#  'fan': '5',
#  'crochet crop': '3',
#  'bleach': '2',
#  'laser': '5',
#  'faux leather paneled': '3',
#  'cover-up': '3',
#  'tonal': '1',
#  'cable': '2',
#  'crossback': '4',
#  'roll': '5',
#  'button': '4',
#  'drape-front': '4',
#  'diamond print': '1',
#  'boxy pocket': '4',
#  'minnie': '5',
#  'leave': '1',
#  'open-back': '4',
#  'embroidered peasant': '3',
#  'knit striped': '1',
#  'skort': '3',
#  'neck ribbed': '4',
#  'round': '3',
#  'neoprene': '2',
#  'bell-sleeve': '4',
#  'floral mini': '3',
#  'ornate paisley': '1',
#  'ornate': '1',
#  'fold-over': '3',
#  'crop': '3',
#  'elegant': '5',
#  'mixed print': '1',
#  'summer': '5',
#  'leather-trimmed': '4',
#  'run': '5',
#  'ribbed stripe': '1',
#  'acid': '2',
#  'dolman': '4',
#  'folk': '1',
#  'floral lace skater': '3',
#  'cargo': '3',
#  'scuba skater': '3',
#  'power': '5',
#  'barbie': '5',
#  'longline': '3',
#  'sun': '5',
#  'tie-back': '4',
#  'stars': '5',
#  'vented hem': '4',
#  'contrast trim': '4',
#  'elasticized': '2',
#  'classic crew neck': '4',
#  'mosaic print': '1',
#  'bird': '1',
#  'contrast': '4',
#  'led': '2',
#  'clashist': '1',
#  'pencil': '3',
#  'festive': '5',
#  'soft': '5',
#  'kangaroo': '4',
#  'loose': '2',
#  'lace panel': '2',
#  'french': '2',
#  'surfer': '5',
#  'wild': '5',
#  'garden party': '5',
#  'baseball': '5',
#  'knit pocket': '4',
#  'textured': '2',
#  'v-neck': '4',
#  'chino': '2',
#  'buttoned': '4',
#  'distressed low-rise': '3',
#  'abstract chevron': '1',
#  'box': '3',
#  'abstract paisley': '1',
#  'standout': '5',
#  'crochet embroidered': '2',
#  'distressed': '2',
#  'shift': '3',
#  'lace sheath': '3',
#  'lakers': '5',
#  'bow': '4',
#  'draped surplice': '4',
#  'classic knit': '2',
#  'popcorn': '5',
#  'nylon': '2',
#  'york': '5',
#  'crochet floral': '1',
#  'puffer': '3',
#  'love': '5',
#  'rolling stones': '5',
#  'paradise': '5',
#  'strap': '4',
#  'tartan': '2',
#  'chunky': '2',
#  'mickey mouse': '5',
#  'boxy': '3',
#  'tie-neck': '4',
#  'mock-neck': '4',
#  'cloud': '2',
#  'lace shift': '3',
#  'sporty': '5',
#  'zip': '4',
#  'bleached denim': '2',
#  'doodle': '5',
#  'chiffon floral': '1',
#  'knit shawl': '4',
#  'cap-sleeve': '4',
#  'rustic': '5',
#  'zig': '1',
#  'capri': '3',
#  'camera': '5',
#  'graphic muscle': '3',
#  'frida': '5',
#  'overlay sheath': '3',
#  'crepe woven': '2',
#  'sunburst': '5',
#  'pleated': '2',
#  'marled stripe': '1',
#  'eyelash lace': '2',
#  'flat': '4',
#  'diamond': '1',
#  'babe': '5',
#  'french terry': '2',
#  'faux leather skater': '3',
#  'linen-blend': '1',
#  'stone': '2',
#  'muse': '5',
#  'glass': '2',
#  'print surplice': '4',
#  'batwing': '4',
#  'keyhole': '4',
#  'varsity': '5',
#  'palm springs': '1',
#  'marble print': '1',
#  'bodycon': '3',
#  'studded': '2',
#  'faux leather-paneled': '3',
#  'mid rise skinny': '3',
#  'sequined': '2',
#  'graphic': '1',
#  'belted maxi': '4',
#  'back knit': '4',
#  'tokyo': '5',
#  'belted floral print': '4',
#  'gaucho': '3',
#  'm-slit': '4',
#  'midi': '3',
#  'v-cut': '4',
#  'zip-front': '4',
#  'cat': '5',
#  'print racerback': '4',
#  'striped': '1',
#  'high-slit': '4',
#  'tropical': '5',
#  'marble': '1',
#  'chunky knit': '2',
#  'heart': '1',
#  'shark': '5',
#  'lace print': '2',
#  'cowl': '4',
#  'lace-up': '4',
#  'dolphin': '4',
#  'slit': '4',
#  'embroidered mesh': '2',
#  'dropped': '4',
#  'slip': '3',
#  'pullover': '3',
#  'chic': '5',
#  'sheer-paneled': '2',
#  'cardio': '5',
#  'tapestry': '2',
#  'low-rise': '3',
#  'daring': '5',
#  'fuzzy knit': '2',
#  'asymmetrical hem': '4',
#  'illusion neckline': '4',
#  'paisley print': '1',
#  'floral print': '1',
#  'lounge': '5',
#  'cotton knit': '2',
#  'monroe': '5',
#  'animal': '1',
#  'elephant': '4',
#  'embroidered floral': '1',
#  'cheetah': '1',
#  'bandana': '1',
#  'leopard print': '1',
#  'beach': '5',
#  'cuffed': '4',
#  'a-line': '3',
#  'embellished': '2',
#  'map': '5',
#  'rise': '3',
#  'palm print': '1',
#  'swing': '3',
#  'stripes': '1',
#  'mesh': '2',
#  'slub-knit': '2',
#  'crisscross-back': '4',
#  'taco': '5',
#  'floral': '1',
#  'free spirit': '5',
#  'speckled': '1',
#  'flutter': '4',
#  'open-knit': '4',
#  'animal print': '1',
#  'tile': '2',
#  'crepe': '2',
#  'tupac': '5',
#  'denim drawstring': '2',
#  'drop waist': '4',
#  'mesh panel': '2',
#  'floral lace': '2',
#  'straight-leg': '3',
#  'brushstroke print': '1',
#  'linen': '1',
#  'shore': '5',
#  'geo print': '1',
#  'splatter': '1',
#  'classic pocket': '4',
#  'fit skinny': '3',
#  'kurt': '3',
#  'dream': '5',
#  'cute': '5',
#  'lace skater': '3',
#  'grid print': '1',
#  'lace-trimmed': '4',
#  'leather-paneled': '2',
#  'classic skinny': '3',
#  'joie': '5',
#  'single-button': '4',
#  'baroque print': '1',
#  'flounce': '4',
#  'nets': '2',
#  'split-neck': '4',
#  'galaxy': '5',
#  'dreamer': '5',
#  'classic denim': '2',
#  'ruched': '2',
#  'faux leather pencil': '3',
#  'fit': '3',
#  'la': '5',
#  'deep-v': '4',
#  'abstract geo': '1',
#  'floral midi': '3',
#  'colorblock pocket': '4',
#  'destroyed': '5',
#  'back cutout': '4',
#  'arrow collar': '4',
#  'bermuda': '3',
#  'denim shift': '3',
#  'high-rise': '3',
#  'van': '5',
#  'bow-back': '4',
#  'tie-front': '4',
#  'belted': '4',
#  'roses': '5',
#  'coffee': '5',
#  'floral flutter': '1',
#  'denim utility': '2',
#  'lace-trim': '4',
#  'fit flare': '3',
#  'foulard': '2',
#  'colorblocked': '1',
#  'popover': '3',
#  'belted lace': '4',
#  'giraffe': '1',
#  'asymmetrical': '3',
#  'kiss': '5',
#  'nyc': '5',
#  'oxford': '5',
#  'open-shoulder': '4',
#  'giraffe print': '1',
#  'smocked': '3',
#  'leather peplum': '4',
#  'frayed': '2',
#  'fringed': '4',
#  'sleeve': '4',
#  'wash': '2',
#  'lace paneled': '2',
#  'classic v-neck': '4',
#  'trimmed': '4',
#  'mob': '5',
#  'brooklyn nets': '5',
#  'fisherman': '5',
#  'longline shirt': '3',
#  'knit trapeze': '3',
#  'pizza': '5',
#  'print scuba': '2',
#  'marled': '1',
#  'cropped knit': '3',
#  'ruffle': '2',
#  'chevron': '1',
#  'chiffon': '2',
#  'eyelash': '2',
#  'windowpane': '3',
#  'bird print': '1',
#  'waffle': '2',
#  'oil': '2',
#  'faux leather varsity': '3',
#  'logo': '5',
#  'girl': '5',
#  'halen': '5',
#  'refined': '5',
#  'braided': '4',
#  'trench': '5',
#  'canvas': '2',
#  'flower': '1',
#  'pom-pom': '1',
#  'tribal-inspired': '1',
#  'striped v-neck': '4',
#  'washed': '2',
#  'stone washed': '2',
#  'embroidered woven': '2',
#  'purl': '2',
#  'bow-front': '4',
#  'print': '1',
#  'darling': '5',
#  'utility': '5',
#  'red': '5',
#  'smock': '3',
#  'chambray': '2',
#  'embroidered gauze': '2',
#  'workout': '5',
#  'boat neck': '4',
#  'beaded shift': '3',
#  'hepburn': '5',
#  'leather trimmed': '4',
#  'matelot': '5',
#  'california': '5',
#  'rebel': '5',
#  'zip-up': '4',
#  'training': '5',
#  'tulle': '2',
#  'knit': '2',
#  'cutout lace': '2',
#  'backless': '4',
#  'shaggy': '2',
#  'draped open-front': '4',
#  'faux leather-trimmed': '4',
#  'floral surplice': '4',
#  'rose skater': '3',
#  'flare': '3',
#  'flawless': '5',
#  'print v-neck': '4',
#  'daisy': '1',
#  'perforated': '2',
#  'lace-paneled': '2',
#  'faux leather mini': '3',
#  'high-waisted': '4',
#  'knit skater': '3',
#  'americana': '5',
#  'netted': '2',
#  'fancy': '5',
#  'scalloped': '4',
#  'belted plaid': '4',
#  'knit pencil': '3',
#  'ethereal': '5',
#  'ladder-back': '4',
#  'cuffed-sleeve': '4',
#  'glitter': '2',
#  'heroes': '5',
#  'hood': '4',
#  'geo stripe': '1',
#  'city': '5',
#  'sheer': '2',
#  'killin': '5',
#  'checked': '1',
#  'cami maxi': '3',
#  'abstract print': '1',
#  'pleat': '2',
#  'girls': '5',
#  'twisted': '4',
#  'collar': '4',
#  'abstract floral print': '1',
#  'paint': '1',
#  'fair isle': '2',
#  'new york': '5',
#  'modernist': '5',
#  'combo maxi': '3',
#  'ankle': '3',
#  'print shift': '3',
#  'cable knit': '2',
#  'asymmetric': '3',
#  'sateen': '2',
#  'drapey': '3',
#  'houndstooth': '1',
#  'rhinestone': '2',
#  'draped': '4',
#  'lace sleeve': '4',
#  'zeppelin': '5',
#  'embroidered fit': '3',
#  'hem': '4',
#  'baja': '3',
#  'fuzzy': '2',
#  'leather skater': '3',
#  'eyelash knit': '2',
#  'boyfriend': '5',
#  'velveteen': '2',
#  'tunic': '3',
#  'two-button': '4',
#  'cuffed denim': '2',
#  'structured': '1',
#  'tree': '5',
#  'bed': '5',
#  'youth': '5',
#  'box pleat': '3',
#  'southwestern-inspired': '1',
#  'moto': '3',
#  'geo pattern': '1',
#  'light': '5',
#  'one-shoulder': '4',
#  'gauze maxi': '3',
#  'abstract chevron print': '1',
#  'scuba': '2',
#  'mickey': '5',
#  'mini': '3',
#  'rad': '5',
#  'seam': '2',
#  'mina': '5',
#  'high-rise skinny': '3',
#  'enchanted': '5',
#  'faux': '2',
#  'curved': '4',
#  'one-button': '4',
#  'floral-embroidered': '1',
#  'triangle': '5',
#  'hooded': '4',
#  'genuine': '5',
#  'flared': '3',
#  'layered': '2',
#  'boho': '5',
#  'cropped': '3',
#  'metallic': '2',
#  'draped shawl': '4',
#  'dip-dyed': '2',
#  'graphic racerback': '4',
#  'square': '3',
#  'terry': '2',
#  'sleeveless': '4',
#  'performance': '5',
#  'crinkled': '2',
#  'shawl': '4',
#  'lace peplum': '4',
#  'butterfly': '1',
#  'boxy knit': '3',
#  'track': '5',
#  'floral pattern': '1',
#  'zigzag': '1',
#  'brooklyn': '5',
#  'bustier': '3',
#  'crochet': '2',
#  'rugby stripe': '1',
#  'tasseled': '4',
#  'patterned': '1',
#  'floral paisley': '1',
#  'knit mini': '3',
#  'mineral': '2',
#  'quilted': '2',
#  'peplum': '4',
#  'heathered v-neck': '4',
#  'flutter-sleeve': '4',
#  'beaded': '2',
#  'cami': '3',
#  'camo': '1',
#  'clean': '2',
#  'pineapple': '5',
#  'dolman-sleeve': '4',
#  'skinny': '3',
#  'y-back': '4',
#  'dot': '1',
#  'stones': '2',
#  'lace midi': '3',
#  'heathered': '2',
#  'plaid shirt': '2',
#  'curved hem': '4',
#  'biker': '5',
#  'scoop': '4',
#  'classic woven': '2',
#  'southwestern': '1',
#  'neck striped': '4',
#  'basquiat': '5',
#  'seersucker': '2',
#  'foldover': '3',
#  'abstract pattern': '1',
#  'heart print': '1',
#  'distressed mid-rise': '3',
#  'chiffon surplice': '4',
#  'raglan': '4',
#  'combo': '3',
#  'elephant print': '4',
#  'circle': '1',
#  'chiffon paneled': '3',
#  'beaded chiffon': '2',
#  'rib-knit': '2',
#  'beatles': '5',
#  'high-slit maxi': '4',
#  'neon': '2',
#  'lace layered': '2',
#  'coast': '5',
#  'pocket': '4',
#  'crochet fringe': '4',
#  'twill': '2',
#  'bead': '2',
#  'dye': '2',
#  'floral textured': '1',
#  'botanical': '1',
#  'crepe shift': '3',
#  'gem': '2',
#  'floral lace mini': '3',
#  'leather mini': '3',
#  'ribbed-knit': '2',
#  'bodycon midi': '3',
#  'leather': '2',
#  'floral print strapless': '4',
#  'minnie mouse': '5',
#  'guns': '5',
#  'tulip-back': '4',
#  'pima': '2',
#  'baroque': '1',
#  'high-waist': '4',
#  'spotted': '1',
#  'art': '5',
#  'fair': '2',
#  'side slit': '4',
#  'paisley': '1',
#  'blurred': '5',
#  'mid rise': '3',
#  'pink': '5',
#  'ikat': '1',
#  'sea': '5',
#  'contrast-trimmed': '4',
#  'boxy lace': '3',
#  'origami': '2',
#  'faux leather moto': '3',
#  'distressed skinny': '3',
#  'cutout-back': '4',
#  'pattern': '1',
#  'please': '5',
#  'dip-dye': '2',
#  'knit v-neck': '4',
#  'colorblock': '1',
#  'floral skater': '3',
#  'embroidery': '2',
#  'classic cotton': '2',
#  'mandarin': '5',
#  'cutout': '3',
#  'oversized': '3',
#  'textured woven': '2',
#  'crocheted': '2',
#  'checkered': '1',
#  'long sleeve': '4',
#  'vertical': '3',
#  'zipped': '4',
#  'collar lace': '4',
#  'pleated skater': '3',
#  'floral print skater': '3',
#  'southwestern-print': '1',
#  'bandana print': '1',
#  'medallion': '1',
#  'convertible': '4',
#  'cities': '5',
#  'zipper': '4',
#  'marilyn': '5',
#  'cloud wash': '2',
#  'rugby': '5',
#  'reverse': '5',
#  'faux suede': '2',
#  'long-sleeve': '4',
#  'wifey': '5',
#  'lace maxi': '3',
#  'back lace': '4',
#  'knit raglan': '4',
#  'side-slit': '4',
#  'roman': '5',
#  'hooded maxi': '4',
#  'suede': '2',
#  'floral shift': '3',
#  'high-low': '3',
#  'studio': '5',
#  'print shirt': '1',
#  'tie-dye': '2',
#  'medallion print': '1',
#  'long-sleeved': '4',
#  'bell': '4',
#  'sweet': '5',
#  'denim': '2',
#  'polka dot': '1',
#  'scallop': '4',
#  'strapless tribal': '4',
#  'polo': '3',
#  'springs': '5',
#  'crew': '4',
#  'beaded sheer': '2',
#  'chenille': '2',
#  'panel': '2',
#  'double-breasted': '4',
#  'tulip': '3',
#  'devil': '5',
#  'abstract floral': '1',
#  'stretch': '2',
#  'west': '5',
#  'faux fur': '2',
#  'chambray drawstring': '2',
#  'flounce maxi': '3',
#  'geo': '1',
#  'applique': '2',
#  'strappy': '4',
#  'basic': '5',
#  'flounced': '4',
#  'feather': '2',
#  'botanical print': '1',
#  'floral pleated': '3',
#  'abstract geo print': '1',
#  'dots': '1',
#  'life': '5',
#  'shopping': '5',
#  'classic crew': '4',
#  'crisscross': '4',
#  'knit longline': '3',
#  'topstitched': '4',
#  'acid wash': '2',
#  'wake': '5',
#  'faux shearling': '2',
#  'chiffon shift': '3',
#  'spirit': '5',
#  'kangaroo pocket': '4',
#  'knit stripe': '1',
#  'crochet-trimmed': '4',
#  'plaid': '2',
#  'fur': '2',
#  'crochet-paneled': '3',
#  'clean wash': '2',
#  'raw': '3',
#  'solid': '5',
#  'caged': '3',
#  'tribal': '1',
#  'lace pencil': '3',
#  'zippered': '4',
#  'knit lace': '2',
#  'chevron print': '1',
#  'stretch-knit': '2',
#  'texas': '5',
#  'collarless': '4',
#  'leaf print': '1',
#  'm-slit maxi': '4',
#  'snoopy': '5',
#  'ombre': '1',
#  'loop': '2',
#  'print satin': '2',
#  'paint splatter': '1',
#  'strapless': '4',
#  'floral mesh': '2',
#  'ikat print': '1',
#  'knit open': '4',
#  'mesh overlay': '2',
#  'skinny stretch': '3',
#  'varsity-striped': '1',
#  'embroidered': '2',
#  'audrey': '5',
#  'blah': '5',
#  'abstract diamond': '1',
#  'windbreaker': '3',
#  'self-tie': '4',
#  'rib': '2',
#  'everyday': '5',
#  'breton': '1',
#  'pointelle': '2',
#  'v-back': '4',
#  'watercolor': '1',
#  'shirt': '3',
#  'breton stripe': '1',
#  'pinstriped': '1',
#  'kaleidoscope print': '1',
#  'bella': '5',
#  'drawstring': '4',
#  'split': '4',
#  'belted chiffon': '4',
#  'party': '5',
#  'butterfly print': '1',
#  'isle': '5',
#  'pan': '5',
#  'voyager': '5',
#  'hooded utility': '4',
#  'flowy': '3',
#  'kahlo': '5',
#  'dreamcatcher': '5',
#  'cutout maxi': '3',
#  'raglan sleeve': '4',
#  'pinstripe': '1',
#  'leopard': '1',
#  'tassel': '4',
#  'running': '5',
#  'lace mini': '3',
#  'stripe': '1',
#  'neckline': '4',
#  'brocade': '2',
#  'crochet lace': '2',
#  'mosaic': '1',
#  'kid': '5',
#  'flirty': '5',
#  'floral knit': '2',
#  'cross-back': '4',
#  'suspender': '4',
#  'nautical stripe': '1',
#  'patchwork': '2',
#  'pintuck pleated': '2',
#  'quirky': '5',
#  'tiered': '2',
#  'ringer': '1',
#  'classic striped': '1',
#  'edge': '5',
#  'wide-leg': '3',
#  'swiss': '5',
#  'denim skater': '3',
#  'eagle': '5',
#  'muscle': '3',
#  'back bow': '4',
#  'ny': '5',
#  'safari': '5',
#  'vent': '4',
#  'athletic': '5',
#  'box-pleated': '3',
#  'drop-sleeve': '4',
#  'floral lace sheath': '3',
#  'tasmanian': '5',
#  'camouflage': '1',
#  'babydoll': '5',
#  'loose-knit': '2',
#  'satin': '2',
#  'print tulip': '3',
#  'cut': '3',
#  'cowl neck': '4',
#  'sunflower': '5',
#  'flat-front': '4',
#  'rose': '5',
#  'striped trapeze': '3',
#  'sky': '5',
#  'mirrored': '5',
#  'lattice': '2',
#  'button-front': '4',
#  'maxi': '3',
#  'folk print': '1',
#  'snap': '5',
#  'bejeweled': '2',
#  'smart': '5',
#  'crochet overlay': '2',
#  'swim': '5',
#  'shoulder': '4',
#  'knee-length': '3',
#  'big': '3',
#  'off-the-shoulder': '4',
#  'crochet mesh': '2',
#  'bib': '3',
#  'classic fit': '3',
#  'dark': '5',
#  'neck skater': '4',
#  'heathered stripe': '1',
#  'grid': '1',
#  'bandage': '3',
#  'multi-stripe': '1',
#  'lace overlay': '2',
#  'fitted v-neck': '4',
#  'lady': '5',
#  'cutout sheath': '3',
#  'mod': '5',
#  'painted': '1',
#  'ponte': '2',
#  'shirred': '2',
#  'miami': '5',
#  'mock neck': '4',
#  'seaside': '5',
#  'candy': '5',
#  'lightning': '5',
#  'leather paneled': '2',
#  'heathered knit': '2',
#  'night': '5',
#  'eyelet': '2',
#  'notorious': '5',
#  'tower': '5',
#  'print strappy': '4',
#  'daisy print': '1',
#  'sequin': '2',
#  'kaleidoscope': '1',
#  'rise skinny': '3',
#  'ditsy floral print': '1',
#  'turtle-neck': '4',
#  'spongebob': '5',
#  'doll': '5',
#  'crew neck': '4',
#  'leather pencil': '3',
#  'embroidered gauze peasant': '3',
#  'flat front': '4',
#  't-back': '4',
#  'pleated woven': '2',
#  'luxe': '5',
#  'ornate print': '1',
#  'leaf': '1',
#  'ruffled': '2',
#  'overlay': '2',
#  'tube': '3',
#  'fox': '5',
#  'slick': '2',
#  'moon': '5',
#  'peasant': '3',
#  'retro': '5',
#  'mandala print': '1',
#  'mid-rise': '3',
#  'organza': '2',
#  'boxy striped': '1',
#  'ripped': '2',
#  'coated': '2',
#  'bold': '5',
#  'posh': '5',
#  'damask': '2',
#  'open-front': '4',
#  'herringbone': '2',
#  'low-rise skinny': '3',
#  'chiffon layered': '2',
#  'brushstroke': '1',
#  'mesh-paneled': '2',
#  'lover': '5',
#  'yoke': '5',
#  'slub': '2',
#  'embroidered maxi': '3',
#  'collarless faux': '4',
#  'back striped': '4',
#  'cozy': '3',
#  'meow': '5',
#  'island': '5',
#  'ribbed': '2',
#  'fringe': '4',
#  'print smocked': '3',
#  'angeles': '5',
#  'mixed': '1',
#  'lace mesh': '2',
#  'chiffon-paneled': '3',
#  'dolphin hem': '4',
#  'printed': '1',
#  'cutoff': '3',
#  'chiffon lace': '2',
#  'gauze': '2',
#  'two-tone': '1',
#  'mesh racerback': '4',
#  'civil': '5',
#  'southwestern-patterned': '1',
#  'floral peasant': '3',
#  'seamless': '2',
#  'lace sheer': '2',
#  'boxy crop': '3',
#  'wrap': '3',
#  'rugby striped': '1',
#  'drop-waist': '4',
#  'france': '5',
#  'slim': '3',
#  'gauzy': '2',
#  'palm tree': '1',
#  'floral maxi': '3',
#  'dolman sleeve': '4',
#  'knit maxi': '3',
#  'leather quilted': '2',
#  'trapeze': '3',
#  'notched collar': '4',
#  'split-back': '4',
#  'fluted': '4',
#  'mesh-trimmed': '4',
#  'wildflower': '5',
#  'denim pencil': '3',
#  'dynamite': '5',
#  'ditsy': '1',
#  'beaded collar': '4',
#  'harem': '3',
#  'medium': '3',
#  'grunge': '5',
#  'pintuck': '2',
#  'relaxed': '5',
#  'eyelet fit': '3',
#  'leather varsity': '3',
#  'sophisticated': '1',
#  'flutter sleeve': '4',
#  'lace pleated': '2',
#  'heat': '5',
#  'mesh paneled': '2',
#  'cable-knit': '2',
#  'denim shirt': '2',
#  'print strapless': '4',
#  'corduroy': '2',
#  'cotton drawstring': '2',
#  'raw-cut': '3',
#  'paneled': '2',
#  'raga': '5',
#  'floral print surplice': '4',
#  'morning': '5',
#  'high-neck': '4',
#  'semi-sheer': '2',
#  'print woven': '1',
#  'woke': '5',
#  'abstract stripe': '1',
#  'faded': '2',
#  'palm': '1',
#  'georgette': '2',
#  'trim': '4',
#  'faux-wrap': '3',
#  'abstract printed': '1',
#  'pin': '4',
#  'deep v-neck': '4',
#  'abstract': '1',
#  'sweetheart': '5',
#  'crocheted lace': '2',
#  'chiffon shirt': '2',
#  'rolling': '5',
#  'nautical': '1',
#  'sheath': '3',
#  'defyant': '5',
#  'cotton': '2',
#  'marilyn monroe': '5',
#  'rainbow': '5',
#  'mid-rise skinny': '3',
#  'yoga': '5',
#  'dotted': '1',
#  'pintucked': '2',
#  'loyal': '5',
#  'field': '5',
#  'thermal': '5',
#  'gathered waistline': '4',
#  'leather moto': '3',
#  'mixed stripe': '1',
#  'chiffon pleated': '3',
#  'illusion': '4',
#  'mock': '4',
#  'print skater': '3',
#  'skater': '3',
#  'lapel': '4',
#  'trouser': '3',
#  'star': '5',
#  'lace trim': '4',
#  'shredded': '2',
#  'reversible': '5',
#  'eiffel': '5',
#  'woven': '2',
#  'foil': '1',
#  'trouble': '5',
#  'faux leather': '2',
#  'chiffon maxi': '3',
#  'velvet': '2',
#  'belted floral': '4',
#  'weekend': '5',
#  'desert': '5',
#  'cotton-blend': '2',
#  'regime': '5',
#  'shearling': '2',
#  'bleached': '2',
#  'surplice': '4',
#  'collared': '4',
#  'inset': '5',
#  'floyd': '5',
#  'jacquard': '2',
#  'fitted': '3',
#  'cinched': '4',
#  'fresh': '5',
#  'print smock': '3'}

# %%
import pandas as pd
df_attr = pd.DataFrame()

df_attr = df_attr.from_dict(attr_type.items())

# %%
df_attr.columns = ['Attribute','Type']

# %%
df_attr
# Out:
#              Attribute Type
# 0              gingham    2
# 1         crochet knit    2
# 2                 lace    2
# 3              knotted    4
# 4     embroidered lace    2
# 5                sleek    2
# 6               toggle    4
# 7              classic    5
# 8               dainty    5
# 9            racerback    4
# 10                lacy    2
# 11             mandala    1
# 12             slouchy    3
# 13              venice    5
# 14                  pj    5
# 15        ditsy floral    1
# 16               paris    5
# 17             burnout    2
# 18        crochet maxi    3
# 19           sparkling    2
# 20        mineral wash    2
# 21             patched    2
# 22                bike    5
# 23          scoop-neck    4
# 24       gauze peasant    3
# 25               smile    5
# 26               tweed    2
# 27         ruffle trim    4
# 28         twist-front    4
# 29   embroidered shift    3
# ..                 ...  ...
# 970             skater    3
# 971              lapel    4
# 972            trouser    3
# 973               star    5
# 974          lace trim    4
# 975           shredded    2
# 976         reversible    5
# 977             eiffel    5
# 978              woven    2
# 979               foil    1
# 980            trouble    5
# 981       faux leather    2
# 982       chiffon maxi    3
# 983             velvet    2
# 984      belted floral    4
# 985            weekend    5
# 986             desert    5
# 987       cotton-blend    2
# 988             regime    5
# 989          shearling    2
# 990           bleached    2
# 991           surplice    4
# 992           collared    4
# 993              inset    5
# 994              floyd    5
# 995           jacquard    2
# 996             fitted    3
# 997            cinched    4
# 998              fresh    5
# 999        print smock    3
#
# [1000 rows x 2 columns]

# %%
df_attr.groupby(by='Type').count()
# Out:
#       Attribute
# Type
# 1           156
# 2           218
# 3           180
# 4           216
# 5           230

# %%
df_attr = df_attr.sort_values(['Attribute'], ascending=True)

# %%
print df_attr.columns
# Out:
# Index([u'Attribute', u'Type'], dtype='object')

# %% [markdown]
# ## Obtain Data from attr_type_path

# %%
df_columns = []
for i in df_attr['Attribute']:
    df_columns.append(i)

# %%
df = pd.read_csv(attr_path2, delim_whitespace=True, header=None, names=df_columns)

# %%
df.head()
# Out:
#                                                  a-line  abstract  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg      -1        -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg      -1        -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg      -1        -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg      -1        -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg      -1        -1
#
#                                                  abstract chevron  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                -1
#
#                                                  abstract chevron print  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                      -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                      -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                      -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                      -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                      -1
#
#                                                  abstract diamond  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                -1
#
#                                                  abstract floral  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg               -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg               -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg               -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg               -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg               -1
#
#                                                  abstract floral print  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                     -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                     -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                     -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                     -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                     -1
#
#                                                  abstract geo  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg            -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg            -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg            -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg            -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg            -1
#
#                                                  abstract geo print  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                  -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                  -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                  -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                  -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                  -1
#
#                                                  abstract paisley    ...     \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                -1    ...
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                -1    ...
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                -1    ...
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                -1    ...
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                -1    ...
#
#                                                  zeppelin  zig  zigzag  zip  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg        -1   -1      -1   -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg        -1   -1      -1   -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg        -1   -1      -1   -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg        -1   -1      -1   -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg        -1   -1      -1   -1
#
#                                                  zip-front  zip-pocket  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg         -1          -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg         -1          -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         -1          -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg         -1          -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg         -1          -1
#
#                                                  zip-up  zipped  zipper  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg      -1      -1      -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg      -1      -1      -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg      -1      -1      -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg      -1      -1      -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg      -1      -1      -1
#
#                                                  zippered
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg        -1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg        -1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg        -1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg        -1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg        -1
#
# [5 rows x 1000 columns]

# %%
df2 = pd.read_csv(img_category_path2, delim_whitespace= True, header=0, names=['category'])

# %%
df2['upper_lower'] = ['1' if i< 21 else '3' if i>36 else '2' for i in df2['category']]

# %%
df2.head()
# Out:
#                                                  category upper_lower
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg         3           1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg         3           1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         3           1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg         3           1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg         3           1

# %%
df2.groupby('upper_lower').count()
# Out:
#              category
# upper_lower
# 1              139709
# 2               58963
# 3               90550

# %%
# combine the two dataframes
df['item_type'] = df2['category']
df['upper_lower'] = df2['upper_lower']

# %%
df = df.replace(-1, 0)

# %%
#df_tf_version = df[df['upper_lower!']!= 3]
#df_tf_version.to_csv('category-tf-all.txt', sep=':')

# %% [markdown]
# ## Extract Upper and Lower

# %%
df_upper = df[df['upper_lower']=='1']
df_lower = df[df['upper_lower']=='2']

# %% [markdown]
# ## Create 5 Category

# %%
d_texture = []
d_fabric = []
d_shape = []
d_part = []
d_style = []

# %%
count = 0
for i,r in df_attr.iterrows():
    x = r["Type"]
    y = r['Attribute']
    if x == "1":
        d_texture.append(y)
    elif x == "2":
        d_fabric.append(y)
    elif x == "3":
        d_shape.append(y)
    elif x == "4":
        d_part.append(y)
    else:
        d_style.append(y)

# %%
df_texture_u = df_upper[d_texture]
df_fabric_u = df_upper[d_fabric]
df_shape_u = df_upper[d_shape]
df_part_u = df_upper[d_part]
df_style_u = df_upper[d_style]

##

df_texture_l = df_lower[d_texture]
df_fabric_l = df_lower[d_fabric]
df_shape_l = df_lower[d_shape]
df_part_l = df_lower[d_part]
df_style_l = df_lower[d_style]

# %% [markdown]
# ## For safe-keeping...

# %%
# copy to new dataframe
df_upper2 = df_upper.copy()
df_lower2 = df_lower.copy()

# %%
df_texture = df[d_texture]
df_fabric = df[d_fabric]
df_shape = df[d_shape]
df_part = df[d_part]
df_style = df[d_style]

##
df_texture_u2 = df_texture_u.copy()
df_fabric_u2 = df_fabric_u.copy()
df_shape_u2 = df_shape_u.copy()
df_part_u2 = df_part_u.copy()
df_style_u2 = df_style_u.copy()

##
df_texture_l2 = df_texture_l.copy()
df_fabric_l2 = df_fabric_l.copy()
df_shape_l2 = df_shape_l.copy()
df_part_l2 = df_part_l.copy()
df_style_l2 = df_style_l.copy()

# %% [markdown]
# ## Functions for Cleaning

# %%
def add_delete(dataframe, to_add, to_delete = []):
    dataframe[to_add] = 0
    for x in to_delete:
        try: 
            dataframe[to_add] += dataframe[x]
            #del dataframe[x]
        except:
            print "Error with: ", x
    dataframe[to_add] = dataframe[to_add].replace(range(1,len(to_delete)+1), 1)

# %%
def extract_column(dataframe, word):
    ls = []
    for x in dataframe.columns:
        if word in x:
            ls.append(x)
    print ls
    return ls

# %%
def order_col(dataframe, show_list = 30):
    print dataframe.sum().sort_values(ascending=False)[:show_list]

# %%
def clean_df(dataframe):
    for col in dataframe:
        if "!" not in col:
            del dataframe[col]

# %%
def total_count(dataframe, show_count = True, delete=False):
    dataframe['total'] = dataframe.sum(axis=1,numeric_only = True)
    if show_count == True:
        print dataframe.groupby(by = 'total').count()
    if delete == True:
        print "Before length :", len(dataframe)
        return dataframe.drop(dataframe[dataframe.total == 0].index)
        print "After length :", len(dataframe)

# %% [markdown]
# ## For df_texture

# %%
# in case we need to start over

df_texture_u = df_upper[d_texture]
df_texture_l = df_lower[d_texture]
df_texture_u2 = df_texture_u.copy()
df_texture_l2 = df_texture_l.copy()

# %%
order_col(df_texture_u)
print ""
order_col(df_texture_l)
# Out:
# print             13725
# floral             7051
# striped            6893
# graphic            6495
# stripe             4751
# printed            2623
# abstract           2339
# floral print       2162
# pattern            2070
# marled             1994
# linen              1866
# dot                1764
# tribal             1655
# polka dot          1579
# colorblock         1513
# paisley             964
# stripes             961
# abstract print      843
# heart               829
# geo                 771
# print shirt         682
# leopard             661
# flower              658
# southwestern        619
# mixed               576
# chevron             571
# diamond             564
# palm                552
# animal              525
# colorblocked        466
# dtype: int64
#
# print             7363
# floral            4145
# striped           1825
# printed           1348
# floral print      1255
# stripe            1230
# tribal            1165
# polka dot          939
# dot                933
# abstract           833
# linen              767
# paisley            665
# leopard            574
# colorblock         510
# daisy              491
# pattern            486
# marled             454
# geo                399
# abstract print     394
# leopard print      374
# camo               360
# stripes            321
# flower             307
# diamond            286
# paisley print      271
# linen-blend        259
# ikat               227
# baroque            221
# chevron            219
# graphic            216
# dtype: int64

# %%
#paisley = extract_column(df_texture, 'paisley')
#add_delete(df_texture_u2, 't_paisley!', paisley)
#add_delete(df_texture_l2, 't_paisley!', paisley)
#
floral = extract_column(df_texture, 'floral')
add_delete(df_texture_u2, 't_floral!', floral)
add_delete(df_texture_l2, 't_floral!', floral)
#
stripe = extract_column(df_texture, 'stripe')
add_delete(df_texture_u2, 't_stripe!', stripe)
add_delete(df_texture_l2, 't_stripe!', stripe)
#
dot = extract_column(df_texture,'dot')
add_delete(df_texture_u2, 't_dot!', dot)
add_delete(df_texture_l2, 't_dot!', dot)
#
#tribal = extract_column(df_texture, 'tribal')
#add_delete(df_texture_u2, 't_tribal!', tribal)
#add_delete(df_texture_l2, 't_tribal!', tribal)
#
#zigzag = extract_column(df_texture, 'zig')
#add_delete(df_texture_u2, 't_zigzag!', zigzag)
#add_delete(df_texture_l2, 't_zigzag!', zigzag)
#
#add_delete(df_texture_u2, 't_print!', ['print','printed', 'graphic'])
#add_delete(df_texture_l2, 't_print!', ['print','printed', 'graphic'])
#
#abstract = extract_column(df_texture, 'abstract')
#add_delete(df_texture_u2, 't_abstract!', abstract)
#add_delete(df_texture_l2, 't_abstract!', abstract)
#
#add_delete(df_texture_u2, 't_animal!', ['leopard','animal'])
#add_delete(df_texture_l2, 't_animal!', ['leopard','animal'])
# Out:
# ['abstract floral', 'abstract floral print', 'chiffon floral', 'crochet floral', 'ditsy floral', 'ditsy floral print', 'embroidered floral', 'floral', 'floral flutter', 'floral paisley', 'floral pattern', 'floral print', 'floral textured', 'floral-embroidered']
# ['abstract stripe', 'boxy striped', 'breton stripe', 'classic striped', 'geo stripe', 'heathered stripe', 'knit stripe', 'knit striped', 'marled stripe', 'mixed stripe', 'multi-stripe', 'nautical stripe', 'nautical striped', 'pinstripe', 'pinstriped', 'ribbed stripe', 'rugby stripe', 'rugby striped', 'stripe', 'striped', 'stripes', 'varsity-striped']
# ['dot', 'dots', 'dotted', 'polka dot']

# %%
clean_df(df_texture_u2)
clean_df(df_texture_l2)

# %%
order_col(df_texture_u2)
# Out:
# t_stripe!    12080
# t_floral!     7098
# t_dot!        2375
# dtype: int64

# %%
total_count(df_texture_u2)
print len(df_texture_u2)
# Out:
#        t_floral!  t_stripe!  t_dot!
# total
# 0         118682     118682  118682
# 1          20522      20522   20522
# 2            484        484     484
# 3             21         21      21
# 139709

# %%
order_col(df_texture_l2)
# Out:
# t_floral!    4160
# t_stripe!    3371
# t_dot!       1192
# dtype: int64

# %%
total_count(df_texture_l2)
print len(df_texture_l2)
# Out:
#        t_floral!  t_stripe!  t_dot!
# total
# 0          50436      50436   50436
# 1           8333       8333    8333
# 2            192        192     192
# 3              2          2       2
# 58963

# %% [markdown]
# ## For df_fabric

# %%
# in case we need to start over
#df_fabric_u = df_upper[d_fabric]
#df_fabric_l = df_lower[d_fabric]
#df_fabric_u2 = df_fabric_u.copy()
#df_fabric_l2 = df_fabric_l.copy()

# %% [markdown]
# ### for the df_fabric (upper)

# %%
order_col(df_fabric_u2)
# Out:
# knit            12628
# lace             6086
# chiffon          6048
# cotton           4307
# crochet          3920
# faux             3919
# leather          3743
# denim            2674
# sheer            2632
# embroidered      2353
# mesh             2317
# woven            2189
# loose            2044
# plaid            1987
# faux leather     1927
# ribbed           1907
# textured         1705
# heathered        1642
# slub             1625
# cable            1610
# fur              1597
# crepe            1477
# pleated          1296
# faux fur         1250
# quilted          1236
# cable knit       1156
# ruffle           1121
# burnout          1077
# french           1063
# beaded           1038
# dtype: int64

# %%
lace = extract_column(df_fabric,'lace')
add_delete(df_fabric_u2, 'f_lace!', lace)
#
#knit = extract_column(df_fabric,'knit')
#add_delete(df_fabric_u2, 'f_knit!', knit)
#
denim = extract_column(df_fabric,'denim')
add_delete(df_fabric_u2, 'f_denim!', denim)
#
chiffon = extract_column(df_fabric, 'chiffon')
add_delete(df_fabric_u2, 'f_chiffon!',  chiffon)
#
cotton = extract_column(df_fabric, 'cotton')
add_delete(df_fabric_u2, 'f_cotton!', cotton )
#
leather = extract_column(df_fabric, 'leather')
add_delete(df_fabric_u2, 'f_leather!', leather )
#
#pleated = extract_column(df_fabric, 'pleat')
#add_delete(df_fabric_u2, 'f_pleated!', pleated )
#
fur = extract_column(df_fabric, 'fur')
add_delete(df_fabric_u2, 'f_fur!', leather)
#
#sheer = extract_column(df_fabric, 'sheer')
#add_delete(df_fabric_u2, 'f_sheer!', sheer)
#
#embroidered = extract_column(df_fabric, 'embroidered')
#add_delete(df_fabric_u2, 'f_embroidered!', embroidered)
# Out:
# ['chiffon lace', 'crochet lace', 'crocheted lace', 'cutout lace', 'embroidered lace', 'eyelash lace', 'floral lace', 'knit lace', 'lace', 'lace layered', 'lace mesh', 'lace overlay', 'lace panel', 'lace paneled', 'lace pleated', 'lace print', 'lace sheer', 'lace-paneled']
# ['bleached denim', 'classic denim', 'cuffed denim', 'denim', 'denim drawstring', 'denim shirt', 'denim utility']
# ['beaded chiffon', 'chiffon', 'chiffon lace', 'chiffon layered', 'chiffon shirt']
# ['classic cotton', 'cotton', 'cotton drawstring', 'cotton knit', 'cotton-blend']
# ['faux leather', 'leather', 'leather paneled', 'leather quilted', 'leather-paneled']
# ['faux fur', 'fur']

# %%
clean_df(df_fabric_u2)

# %%
order_col(df_fabric_u2)
# Out:
# f_lace!       6357
# f_chiffon!    6048
# f_cotton!     4410
# f_fur!        3767
# f_leather!    3767
# f_denim!      2674
# dtype: int64

# %%
total_count(df_fabric_u2)
print len(df_fabric_u2)
# Out:
#        f_lace!  f_denim!  f_chiffon!  f_cotton!  f_leather!  f_fur!
# total
# 0       117772    117772      117772     117772      117772  117772
# 1        17115     17115       17115      17115       17115   17115
# 2         4566      4566        4566       4566        4566    4566
# 3          248       248         248        248         248     248
# 4            8         8           8          8           8       8
# 139709

# %% [markdown]
# ### For the d_fabric (lower)

# %%
df_fabric_l2 = df_fabric_l.copy()
order_col(df_fabric_l2)
# Out:
# denim           8706
# wash            3809
# distressed      2691
# lace            2553
# leather         2538
# pleated         2537
# knit            2422
# faux            1862
# acid            1775
# cotton          1739
# faux leather    1668
# stretch         1486
# acid wash       1475
# woven           1407
# crochet         1326
# ripped          1093
# chino            944
# embroidered      807
# mesh             725
# terry            720
# french           713
# chambray         672
# plaid            669
# textured         648
# chiffon          644
# french terry     617
# washed           570
# dye              569
# mineral          553
# faded            544
# dtype: int64

# %%
denim = extract_column(df_fabric_l, 'denim')
add_delete(df_fabric_l2, 'f_denim!', denim)
#
#wash = extract_column(df_fabric_l, 'wash')
#add_delete(df_fabric_l2, 'f_wash!', wash)
#
#add_delete(df_fabric_l2, 'f_distressed/ripped!', ['distressed','ripped'])
#
leather = extract_column(df_fabric_l, 'leather')
add_delete(df_fabric_l2, 'f_leather!', leather)
#
cotton = extract_column(df_fabric_l, 'cotton')
add_delete(df_fabric_l2, 'f_cotton!', cotton)
#
knit = extract_column(df_fabric_l, 'knit')
add_delete(df_fabric_l2, 'f_knit!', knit)
#
pleated = extract_column(df_fabric_l, 'pleat')
add_delete(df_fabric_l2, 'f_pleated!', pleated)
#
# Out:
# ['bleached denim', 'classic denim', 'cuffed denim', 'denim', 'denim drawstring', 'denim shirt', 'denim utility']
# ['faux leather', 'leather', 'leather paneled', 'leather quilted', 'leather-paneled']
# ['classic cotton', 'cotton', 'cotton drawstring', 'cotton knit', 'cotton-blend']
# ['cable knit', 'cable-knit', 'chunky knit', 'classic knit', 'cotton knit', 'crochet knit', 'eyelash knit', 'floral knit', 'fuzzy knit', 'heathered knit', 'knit', 'knit lace', 'loose-knit', 'rib-knit', 'ribbed-knit', 'slub-knit', 'stretch-knit']
# ['lace pleated', 'pintuck pleated', 'pleat', 'pleated', 'pleated woven']

# %%
clean_df(df_fabric_l2)

# %%
order_col(df_fabric_l2)
# Out:
# f_denim!      8706
# f_pleated!    2862
# f_leather!    2559
# f_knit!       2536
# f_cotton!     1782
# dtype: int64

# %%
total_count(df_fabric_l2)
print len(df_fabric_l2)
# Out:
#        f_denim!  f_leather!  f_cotton!  f_knit!  f_pleated!
# total
# 0         41344       41344      41344    41344       41344
# 1         16806       16806      16806    16806       16806
# 2           800         800        800      800         800
# 3            13          13         13       13          13
# 58963

# %% [markdown]
# ## For df_shape

# %%
# in case we need to start over
#df_shape_u = df_upper[d_shape]
#df_shape_l = df_lower[d_shape]
#df_shape_u2 = df_shape_u.copy()
#df_shape_l2 = df_shape_l.copy()

# %% [markdown]
# ### For df_shape (upper)

# %%
df_shape_u2 = df_shape_u.copy()
order_col(df_shape_u,20)
# Out:
# shirt           12279
# muscle           5490
# crop             5140
# boxy             3573
# cropped          3024
# longline         2766
# pullover         1836
# oversized        1829
# fit              1532
# peasant          1530
# tunic            1469
# slim             1309
# moto             1180
# cut              1018
# maxi             1012
# cutout            946
# cami              945
# asymmetrical      762
# round             761
# big               755
# dtype: int64

# %%
#crop = extract_column(df_shape_u, 'crop')
#add_delete(df_shape_u2, 's_crop!', crop)
#
#oversized = extract_column(df_shape_u, 'oversized')
#add_delete(df_shape_u2, 's_oversized!', oversized)
#
#fit = extract_column(df_shape_u, 'fit')
#add_delete(df_shape_u2, 's_fit!', fit+['slim'])
#
#cami = extract_column(df_shape_u, 'cami')
#add_delete(df_shape_u2, 's_cami!', cami)
#
#tunic = extract_column(df_shape_u, 'tunic')
#add_delete(df_shape_u2, 's_tunic!', tunic)
#
#asym = extract_column(df_shape_u, 'asym')
#add_delete(df_shape_u2, 's_asymmetrical!', asym)
#

# %%
clean_df(df_shape_u2)
order_col(df_shape_u2)
# Out:
# Series([], dtype: float64)

# %%
total_count(df_shape_u2)
print len(df_shape_u2)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0.0]
# 139709

# %% [markdown]
# ### For ds_shape (lower)

# %%
df_shape_l2 = df_shape_l.copy()
order_col(df_shape_l,20)
# Out:
# skinny     4557
# mini       2979
# pencil     2933
# skater     2026
# maxi       1978
# fit        1645
# slim       1622
# capri      1518
# midi       1453
# rise       1403
# crop        889
# a-line      870
# ankle       859
# cut         801
# cargo       742
# shirt       626
# cropped     586
# harem       522
# medium      509
# bermuda     465
# dtype: int64

# %%
#
#skinny = extract_column(df_shape_l, 'skinny')
#add_delete(df_shape_l2, 's_skinny!', skinny)
#
fit = extract_column(df_shape_l, 'fit')
add_delete(df_shape_l2, 's_fit!', fit+['slim'])
#
pencil = extract_column(df_shape_l, 'pencil')
add_delete(df_shape_l2, 's_pencil!', pencil)
#
#capri = extract_column(df_shape_l, 'capri')
#add_delete(df_shape_l2, 's_capri!', capri)
#
midi = extract_column(df_shape_l, 'midi')
add_delete(df_shape_l2, 's_midi!', midi)
#
mini = extract_column(df_shape_l, 'mini')
add_delete(df_shape_l2, 's_mini!', mini)
#
maxi = extract_column(df_shape_l, 'maxi')
add_delete(df_shape_l2, 's_maxi!', maxi)
# Out:
# ['classic fit', 'embroidered fit', 'eyelet fit', 'fit', 'fit flare', 'fit skinny', 'fitted']
# ['denim pencil', 'faux leather pencil', 'knit pencil', 'lace pencil', 'leather pencil', 'pencil']
# ['bodycon midi', 'floral midi', 'lace midi', 'midi']
# ['faux leather mini', 'floral lace mini', 'floral mini', 'knit mini', 'lace mini', 'leather mini', 'mini']
# ['cami maxi', 'chiffon maxi', 'combo maxi', 'crochet maxi', 'cutout maxi', 'embroidered maxi', 'floral maxi', 'flounce maxi', 'gauze maxi', 'knit maxi', 'lace maxi', 'maxi']

# %%
clean_df(df_shape_l2)
order_col(df_shape_l2)
# Out:
# s_mini!      2979
# s_pencil!    2933
# s_fit!       2651
# s_maxi!      1978
# s_midi!      1453
# dtype: int64

# %%
total_count(df_shape_l2)
print len(df_shape_l2)
# Out:
#        s_fit!  s_pencil!  s_midi!  s_mini!  s_maxi!
# total
# 0       47694      47694    47694    47694    47694
# 1       10602      10602    10602    10602    10602
# 2         611        611      611      611      611
# 3          54         54       54       54       54
# 4           2          2        2        2        2
# 58963

# %% [markdown]
# ## For df_part

# %%
# in case we need to start over
#df_part = df[d_part]
#df_part2 = df_part.copy()

# %% [markdown]
# ### For df_part (upper)

# %%
df_part_u2 = df_part_u.copy()
order_col(df_part_u,50)
# Out:
# sleeve           12254
# long sleeve       4688
# collar            4259
# pocket            3967
# v-neck            3756
# button            3375
# hooded            3314
# sleeveless        3265
# trim              2363
# crew              2329
# racerback         2229
# zip               2182
# raglan            2093
# shawl             1889
# dolman            1838
# hem               1729
# crew neck         1700
# fringe            1561
# draped            1495
# collarless        1344
# scoop             1275
# contrast          1251
# shoulder          1164
# open-front        1027
# peplum            1018
# bow                982
# split              957
# batwing            884
# zipper             846
# long-sleeve        725
# open-knit          706
# cowl               666
# fringed            620
# tassel             596
# drawstring         593
# cowl neck          558
# dolman sleeve      528
# collared           512
# surplice           508
# slit               461
# flutter            461
# bell               448
# lapel              434
# lace trim          400
# hood               395
# neckline           392
# belted             387
# boat neck          363
# elephant           341
# trimmed            336
# dtype: int64

# %%
#
sleeve = extract_column(df_part_u, 'sleeve')
sleeveless = extract_column(df_part_u, 'sleeveless')
sleeve = [x for x in sleeve if x not in sleeveless]
#add_delete(df_part_u2, 'p_sleeve!', sleeve)
add_delete(df_part_u2, 'p_sleeveless!', sleeveless)
#
l_sleeve = extract_column(df_part_u, 'long')
add_delete(df_part_u2, 'p_long-sleeve!', l_sleeve)
#
collar = extract_column(df_part_u, 'collar')
collarless = extract_column(df_part_u,'collarless')
collar = [x for x in collar if x not in collarless]
add_delete(df_part_u2, 'p_collar!', collar)
#add_delete(df_part_u2, 'p_collarless!', collarless)
#
pocket = extract_column(df_part_u, 'pocket')
add_delete(df_part_u2, 'p_pocket!', pocket)
#
vneck = extract_column(df_part_u, 'v-neck')
add_delete(df_part_u2, 'p_v-neck!', vneck)
#
button = extract_column(df_part_u, 'button')
add_delete(df_part_u2, 'p_button!', button)
#
hood = extract_column(df_part_u, 'hood')
add_delete(df_part_u2, 'p_hooded!', hood)
#
zipper = extract_column(df_part_u, 'zip')
add_delete(df_part_u2, 'p_zipper!', zipper)
# Out:
# ['bell-sleeve', 'cap-sleeve', 'cuffed-sleeve', 'dolman sleeve', 'dolman-sleeve', 'drop-sleeve', 'flutter sleeve', 'flutter-sleeve', 'lace sleeve', 'long sleeve', 'long-sleeve', 'long-sleeved', 'raglan sleeve', 'sleeve', 'sleeveless']
# ['sleeveless']
# ['long sleeve', 'long-sleeve', 'long-sleeved']
# ['arrow collar', 'beaded collar', 'collar', 'collar lace', 'collared', 'collarless', 'collarless faux', 'notched collar']
# ['collarless', 'collarless faux']
# ['boxy pocket', 'classic pocket', 'colorblock pocket', 'kangaroo pocket', 'knit pocket', 'pocket', 'zip-pocket']
# ['classic v-neck', 'deep v-neck', 'fitted v-neck', 'heathered v-neck', 'knit v-neck', 'print v-neck', 'striped v-neck', 'v-neck']
# ['button', 'button-front', 'buttoned', 'one-button', 'single-button', 'two-button']
# ['hood', 'hooded', 'hooded maxi', 'hooded utility']
# ['zip', 'zip-front', 'zip-pocket', 'zip-up', 'zipped', 'zipper', 'zippered']

# %%
clean_df(df_part_u2)
order_col(df_part_u2)
total_count(df_part_u2)
print len(df_part_u2)
# Out:
# p_long-sleeve!    5533
# p_collar!         4876
# p_button!         4192
# p_pocket!         4005
# p_v-neck!         3756
# p_hooded!         3650
# p_zipper!         3623
# p_sleeveless!     3265
# dtype: int64
#        p_sleeveless!  p_long-sleeve!  p_collar!  p_pocket!  p_v-neck!  \
# total
# 0             110907          110907     110907     110907     110907
# 1              25057           25057      25057      25057      25057
# 2               3409            3409       3409       3409       3409
# 3                319             319        319        319        319
# 4                 17              17         17         17         17
#
#        p_button!  p_hooded!  p_zipper!
# total
# 0         110907     110907     110907
# 1          25057      25057      25057
# 2           3409       3409       3409
# 3            319        319        319
# 4             17         17         17
# 139709

# %% [markdown]
# ### For df_part (lower)

# %%
df_part_l2 = df_part_l.copy()
order_col(df_part_l)
# Out:
# drawstring      3149
# cuffed          1079
# pocket           867
# trim             851
# hem              773
# high-waisted     762
# button           752
# zipper           736
# zip              664
# dolphin          604
# belted           527
# flat             523
# flat front       462
# slit             433
# contrast         363
# lace trim        297
# high-waist       288
# sleeve           277
# zippered         242
# scalloped        238
# split            203
# fringe           187
# crew             169
# tassel           168
# sleeveless       159
# buttoned         148
# bow              146
# flat-front       139
# trimmed          110
# peplum           108
# dtype: int64

# %%
#
#drawstring = extract_column(df_part_u, 'drawstring')
#add_delete(df_part_l2, 'p_drawstring!', drawstring)
#
#cuffed = extract_column(df_part_u, 'cuffed')
#add_delete(df_part_l2, 'p_cuffed!', cuffed)
#
#pocket = extract_column(df_part_u, 'pocket')
#add_delete(df_part_l2, 'p_pocket!', pocket)
#
#button = extract_column(df_part_u, 'button')
#add_delete(df_part_l2, 'p_button!', button)
#
zipper = extract_column(df_part_u, 'zip')
add_delete(df_part_l2, 'p_zipper!', zipper)
#
#high_waist = extract_column(df_part_u, 'high-waist')
#add_delete(df_part_l2, 'p_high-waist!', high_waist)
# Out:
# ['zip', 'zip-front', 'zip-pocket', 'zip-up', 'zipped', 'zipper', 'zippered']

# %%
clean_df(df_part_l2)
order_col(df_part_l2)
total_count(df_part_l2)
print len(df_part_l2)
# Out:
# p_zipper!    1698
# dtype: int64
#        p_zipper!
# total
# 0          57265
# 1           1698
# 58963

# %% [markdown]
# ## For df_style

# %%
# in case we need to start over
df_style = df[d_style]
df_style2 = df_style.copy()

# %%
order_col(df_style_u)
# Out:
# classic      4292
# love         3029
# pink         2922
# red          2836
# summer       2703
# baseball     1821
# shopping     1638
# york         1257
# new york     1208
# rose         1186
# boyfriend    1180
# girls        1143
# basic        1129
# cute         1109
# soft         1060
# chic         1006
# light         942
# boho          926
# girl          912
# la            894
# varsity       882
# solid         810
# sweet         802
# retro         770
# logo          695
# dark          684
# life          667
# city          664
# utility       644
# beach         603
# dtype: int64

# %%
order_col(df_style_l)
# Out:
# classic        2179
# summer         1651
# yoga           1274
# red            1181
# pink           1158
# light          1131
# love            920
# dark            874
# workout         794
# rose            777
# boyfriend       754
# performance     696
# shopping        644
# running         640
# swim            632
# destroyed       616
# girls           610
# soft            589
# cute            543
# solid           494
# tropical        441
# athletic        413
# girl            408
# chic            403
# retro           369
# life            347
# beach           334
# island          332
# sweet           311
# pj              296
# dtype: int64

# %%
#classic = extract_column(df_style, 'classic')
#add_delete(df_style_u2, 'y_classic!', classic)
#add_delete(df_style_l2, 'y_classic!', classic)
#
summer = extract_column(df_style, 'summer')
add_delete(df_style_u2, 'y_summer!', summer)
add_delete(df_style_l2, 'y_summer!', summer)
#
basic = extract_column(df_style,'basic')
add_delete(df_style_u2, 'y_basic!', basic)
add_delete(df_style_l2, 'y_basic!', basic)
#
cute = extract_column(df_style, 'cute')
add_delete(df_style_u2, 'y_cute!', cute)
add_delete(df_style_l2, 'y_cute!', cute)
#
chic = extract_column(df_style, 'chic')
add_delete(df_style_u2, 'y_chic!', chic)
add_delete(df_style_l2, 'y_chic!', chic)
#
retro = extract_column(df_style, 'retro')
add_delete(df_style_u2, 'y_retro!', retro)
add_delete(df_style_l2, 'y_retro!', retro)
#
dark = extract_column(df_style, 'dark')
add_delete(df_style_u2, 'y_dark!', dark)
add_delete(df_style_l2, 'y_dark!', dark)
#
#yoga = extract_column(df_style, 'yoga')
#add_delete(df_style_u2, 'y_yoga!', yoga)
#add_delete(df_style_l2, 'y_yoga!', yoga)
# 
athletic = ['workout', 'running', 'run', 'athletic']
add_delete(df_style_u2, 'y_athletic!', athletic)
add_delete(df_style_l2, 'y_athletic!', athletic)
# Out:
# ['summer']
# ['basic']
# ['cute']
# ['chic']
# ['retro']
# ['dark']

# %%
clean_df(df_style_u2)
order_col(df_style_u2)
total_count(df_style_u2)
print len(df_style_u2)

clean_df(df_style_l2)
order_col(df_style_l2)
total_count(df_style_l2)
print len(df_style_l2)
# Out:
# y_summer!      2703
# y_athletic!    1325
# y_basic!       1129
# y_cute!        1109
# y_chic!        1006
# y_retro!        770
# y_dark!         684
# dtype: int64
#        y_summer!  y_basic!  y_cute!  y_chic!  y_retro!  y_dark!  y_athletic!
# total
# 0         131382    131382   131382   131382    131382   131382       131382
# 1           7940      7940     7940     7940      7940     7940         7940
# 2            376       376      376      376       376      376          376
# 3             10        10       10       10        10       10           10
# 4              1         1        1        1         1        1            1
# 139709
# y_athletic!    1745
# y_summer!      1651
# y_dark!         874
# y_cute!         543
# y_chic!         403
# y_retro!        369
# y_basic!        201
# dtype: int64
#        y_summer!  y_basic!  y_cute!  y_chic!  y_retro!  y_dark!  y_athletic!
# total
# 0          53421     53421    53421    53421     53421    53421        53421
# 1           5308      5308     5308     5308      5308     5308         5308
# 2            224       224      224      224       224      224          224
# 3             10        10       10       10        10       10           10
# 58963

# %%
#df_fabric[df_fabric['pleated'] > 0 ]

# %%
df_upper.head()
# Out:
#                                                  a-line  abstract  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg       0         0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg       0         0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg       0         0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg       0         0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg       0         0
#
#                                                  abstract chevron  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                 0
#
#                                                  abstract chevron print  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                       0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                       0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                       0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                       0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                       0
#
#                                                  abstract diamond  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                 0
#
#                                                  abstract floral  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                0
#
#                                                  abstract floral print  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                      0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                      0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                      0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                      0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                      0
#
#                                                  abstract geo  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg             0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg             0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg             0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg             0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg             0
#
#                                                  abstract geo print  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                   0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                   0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                   0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                   0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                   0
#
#                                                  abstract paisley  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                 0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg                 0
#
#                                                     ...       zigzag  zip  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg     ...            0    0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg     ...            0    0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg     ...            0    0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg     ...            0    0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg     ...            0    0
#
#                                                  zip-front  zip-pocket  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg          0           0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg          0           0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg          0           0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg          0           0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg          0           0
#
#                                                  zip-up  zipped  zipper  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg       0       0       0
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg       0       0       0
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg       0       0       0
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg       0       0       0
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg       0       0       0
#
#                                                  zippered  item_type  \
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg         0          3
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg         0          3
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         0          3
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg         0          3
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg         0          3
#
#                                                  upper_lower
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg            1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg            1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg            1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg            1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg            1
#
# [5 rows x 1002 columns]

# %%
df_lower.head()
# Out:
#                                               a-line  abstract  \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg       0         0
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg       0         0
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg       0         0
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg       0         0
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg       0         0
#
#                                               abstract chevron  \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg                 0
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg                 0
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg                 0
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg                 0
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg                 0
#
#                                               abstract chevron print  \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg                       0
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg                       0
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg                       0
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg                       0
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg                       0
#
#                                               abstract diamond  \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg                 0
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg                 0
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg                 0
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg                 0
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg                 0
#
#                                               abstract floral  \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg                0
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg                0
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg                0
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg                0
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg                0
#
#                                               abstract floral print  \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg                      0
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg                      0
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg                      0
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg                      0
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg                      0
#
#                                               abstract geo  \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg             0
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg             0
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg             0
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg             0
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg             0
#
#                                               abstract geo print  \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg                   0
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg                   0
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg                   0
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg                   0
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg                   0
#
#                                               abstract paisley     ...       \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg                 0     ...
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg                 0     ...
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg                 0     ...
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg                 0     ...
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg                 0     ...
#
#                                               zigzag  zip  zip-front  \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg       0    0          0
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg       0    0          0
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg       0    0          0
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg       0    0          0
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg       0    0          0
#
#                                               zip-pocket  zip-up  zipped  \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg           0       0       0
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg           0       0       0
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg           0       0       0
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg           0       0       0
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg           0       0       0
#
#                                               zipper  zippered  item_type  \
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg       0         0         33
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg       0         0         33
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg       0         0         33
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg       0         0         33
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg       0         0         33
#
#                                               upper_lower
# img/Mineral_Wash_Mini_Skirt/img_00000001.jpg            2
# img/Mineral_Wash_Mini_Skirt/img_00000002.jpg            2
# img/Mineral_Wash_Mini_Skirt/img_00000003.jpg            2
# img/Mineral_Wash_Mini_Skirt/img_00000004.jpg            2
# img/Mineral_Wash_Mini_Skirt/img_00000005.jpg            2
#
# [5 rows x 1002 columns]

# %%
del df_upper['item_type']
del df_upper['upper_lower']
del df_lower['item_type']
del df_lower['upper_lower']

# %%
df_old_u = df_upper.copy()
df_old_l = df_lower.copy()

# %%
df_upper = df_old_u.copy()
df_lower = df_old_l.copy()

# %% [markdown]
# ### Combine dataframes

# %%
#df2_string = df2.to_string()
ls_upper = [df_texture_u2, df_fabric_u2, df_part_u2]  #shape and style ommited
# , df_upper['item_type!'], df_upper['upper_lower!']  
#for x in ls_upper:
#    del x['total']
df_upper = pd.concat(ls_upper, axis=1)
df_upper.head()
df_upper2 = df_upper.copy()

# %%
ls_lower = [df_texture_l2, df_fabric_l2, df_shape_l2, df_part_l2]
# , df_upper['item_type!'], df_upper['upper_lower!']
#for x in ls_upper:
#    del x['total']
df_lower = pd.concat(ls_lower, axis=1)
df_lower.head()
df_lower2 = df_lower.copy()

# %% [markdown]
# ### Inspect Dataframes

# %%
#del df_upper['total']
#del df_lower['total']

# %%
print "Number of Attributes"
print "upper: ", len(df_upper.columns)
print "lower: ", len(df_lower.columns)
# Out:
# Number of Attributes
# upper:  20
# lower:  18

# %%
print "Number of Entries"
print "upper: ", len(df_upper)
print "lower: ", len(df_lower)
# Out:
# Number of Entries
# upper:  139709
# lower:  58963

# %%
df_upper.columns
# Out:
# Index([u't_floral!', u't_stripe!', u't_dot!', u'total', u'f_lace!',
#        u'f_denim!', u'f_chiffon!', u'f_cotton!', u'f_leather!', u'f_fur!',
#        u'total', u'p_sleeveless!', u'p_long-sleeve!', u'p_collar!',
#        u'p_pocket!', u'p_v-neck!', u'p_button!', u'p_hooded!', u'p_zipper!',
#        u'total'],
#       dtype='object')

# %%
df_lower.columns
# Out:
# Index([u't_floral!', u't_stripe!', u't_dot!', u'total', u'f_denim!',
#        u'f_leather!', u'f_cotton!', u'f_knit!', u'f_pleated!', u'total',
#        u's_fit!', u's_pencil!', u's_midi!', u's_mini!', u's_maxi!', u'total',
#        u'p_zipper!', u'total'],
#       dtype='object')

# %%
del df_upper['total']
total_count(df_upper)
# Out:
#        t_floral!  t_stripe!  t_dot!  f_lace!  f_denim!  f_chiffon!  f_cotton!  \
# total
# 0          80521      80521   80521    80521     80521       80521      80521
# 1          41493      41493   41493    41493     41493       41493      41493
# 2          13812      13812   13812    13812     13812       13812      13812
# 3           3254       3254    3254     3254      3254        3254       3254
# 4            553        553     553      553       553         553        553
# 5             71         71      71       71        71          71         71
# 6              5          5       5        5         5           5          5
#
#        f_leather!  f_fur!  p_sleeveless!  p_long-sleeve!  p_collar!  \
# total
# 0           80521   80521          80521           80521      80521
# 1           41493   41493          41493           41493      41493
# 2           13812   13812          13812           13812      13812
# 3            3254    3254           3254            3254       3254
# 4             553     553            553             553        553
# 5              71      71             71              71         71
# 6               5       5              5               5          5
#
#        p_pocket!  p_v-neck!  p_button!  p_hooded!  p_zipper!
# total
# 0          80521      80521      80521      80521      80521
# 1          41493      41493      41493      41493      41493
# 2          13812      13812      13812      13812      13812
# 3           3254       3254       3254       3254       3254
# 4            553        553        553        553        553
# 5             71         71         71         71         71
# 6              5          5          5          5          5

# %%
del df_lower['total']
total_count(df_lower)
# Out:
#        t_floral!  t_stripe!  t_dot!  f_denim!  f_leather!  f_cotton!  f_knit!  \
# total
# 0          28004      28004   28004     28004       28004      28004    28004
# 1          22623      22623   22623     22623       22623      22623    22623
# 2           6941       6941    6941      6941        6941       6941     6941
# 3           1243       1243    1243      1243        1243       1243     1243
# 4            135        135     135       135         135        135      135
# 5             16         16      16        16          16         16       16
# 6              1          1       1         1           1          1        1
#
#        f_pleated!  s_fit!  s_pencil!  s_midi!  s_mini!  s_maxi!  p_zipper!
# total
# 0           28004   28004      28004    28004    28004    28004      28004
# 1           22623   22623      22623    22623    22623    22623      22623
# 2            6941    6941       6941     6941     6941     6941       6941
# 3            1243    1243       1243     1243     1243     1243       1243
# 4             135     135        135      135      135      135        135
# 5              16      16         16       16       16       16         16
# 6               1       1          1        1        1        1          1

# %%
df_upper.rename(columns=lambda x: x.split("!")[0], inplace=True)
df_lower.rename(columns=lambda x: x.split("!")[0], inplace=True)


#df_upper = pd.merge(df_upper, df2, left_index = True, right_index = True)
#df_lower = pd.merge(df_lower, df2, left_index = True, right_index = True)

df_upper.to_csv('category-upper-all-everything.txt', sep=':')
df_lower.to_csv('category-lower-all-everything.txt', sep=':')

# %%
df_upper = total_count(df_upper, show_count = False, delete = True)
df_lower = total_count(df_lower, show_count = False, delete = True)
# Out:
# Before length : 139709
# Before length : 58963

# %%
print "After length : ", len(df_upper)
print "After length : ", len(df_lower)
# Out:
# After length :  59188
# After length :  30959

# %%
list(df_upper)
# Out:
# ['t_floral',
#  't_stripe',
#  't_dot',
#  'f_lace',
#  'f_denim',
#  'f_chiffon',
#  'f_cotton',
#  'f_leather',
#  'f_fur',
#  'p_sleeveless',
#  'p_long-sleeve',
#  'p_collar',
#  'p_pocket',
#  'p_v-neck',
#  'p_button',
#  'p_hooded',
#  'p_zipper',
#  'total']

# %%
list(df2)
# Out:
# ['category', 'upper_lower']

# %%
df_upper.head()
# Out:
#                                                  t_floral  t_stripe  t_dot  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         0         0      0
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg         0         0      0
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg         0         0      0
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg         0         0      0
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg         0         0      0
#
#                                                  f_lace  f_denim  f_chiffon  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg       0        0          0
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg       0        0          0
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg       0        0          0
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg       0        0          0
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg       0        0          0
#
#                                                  f_cotton  f_leather  f_fur  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         0          0      0
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg         0          0      0
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg         0          0      0
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg         0          0      0
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg         0          0      0
#
#                                                  p_sleeveless  p_long-sleeve  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg             1              0
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg             0              1
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg             1              0
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg             0              0
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg             1              0
#
#                                                  p_collar  p_pocket  p_v-neck  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         0         0         1
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg         0         0         0
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg         0         0         0
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg         1         0         1
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg         0         0         0
#
#                                                  p_button  p_hooded  p_zipper  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         0         0         0
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg         0         0         0
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg         0         0         1
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg         0         0         0
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg         1         0         0
#
#                                                  total
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg      4
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg      2
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg      4
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg      4
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg      4

# %%
###TESTING

df_upper2 = df_upper.copy()
df_lower2 = df_lower.copy()

# %%
def drop_lower(dataframe, count):
    del dataframe['total']
    dataframe['total'] = dataframe.sum(axis=1)
    return dataframe.drop(dataframe[dataframe.total < count].index)

# %%
df_upper_al2 = drop_lower(df_upper2, 2)
del df_upper_al2['total']
df_upper_al3 = drop_lower(df_upper2, 3)
del df_upper_al3['total']

# %%
print len(df_upper2)
print len(df_upper_al2)
print len(df_upper_al3)
# Out:
# 59188
# 17695
# 3883

# %%
print len(df_upper2)
order_col(df_upper2)
# Out:
# 59188
# total            81476
# t_stripe         12080
# t_floral          7098
# f_lace            6357
# f_chiffon         6048
# p_long-sleeve     5533
# p_collar          4876
# f_cotton          4410
# p_button          4192
# p_pocket          4005
# f_leather         3767
# f_fur             3767
# p_v-neck          3756
# p_hooded          3650
# p_zipper          3623
# p_sleeveless      3265
# f_denim           2674
# t_dot             2375
# dtype: int64

# %%
print len(df_upper_al2)
order_col(df_upper_al2)
# Out:
# 17695
# t_stripe         3871
# f_fur            3767
# f_leather        3767
# f_chiffon        3354
# p_long-sleeve    3104
# t_floral         2968
# f_lace           2752
# p_collar         2390
# f_cotton         2107
# p_button         2024
# p_pocket         1757
# p_zipper         1695
# p_v-neck         1605
# p_sleeveless     1584
# p_hooded         1264
# t_dot            1039
# f_denim           935
# dtype: int64

# %%
print len(df_upper_al3)
order_col(df_upper_al3)
# Out:
# 3883
# f_fur            1263
# f_leather        1263
# p_long-sleeve    1182
# f_chiffon        1152
# p_collar          981
# t_stripe          826
# t_floral          790
# f_lace            749
# p_button          672
# p_zipper          590
# f_cotton          584
# p_sleeveless      520
# p_v-neck          425
# p_hooded          411
# p_pocket          362
# t_dot             329
# f_denim           260
# dtype: int64

# %%
#del df_lower2['p_button!']
#del df_lower2['p_pocket!']
#del df_lower2['t_animal!']
#del df_lower2['t_paisley!']

# %%
df_lower_al2 = drop_lower(df_lower2, 2)
del df_lower_al2['total']
df_lower_al3 = drop_lower(df_lower2, 3)
del df_lower_al3['total']

# %%
print len(df_lower2)
print len(df_lower_al2)
print len(df_lower_al3)
# Out:
# 30959
# 8336
# 1395

# %%
print len(df_lower2)
order_col(df_lower2)
# Out:
# 30959
# total        40860
# f_denim       8706
# t_floral      4160
# t_stripe      3371
# s_mini        2979
# s_pencil      2933
# f_pleated     2862
# s_fit         2651
# f_leather     2559
# f_knit        2536
# s_maxi        1978
# f_cotton      1782
# p_zipper      1698
# s_midi        1453
# t_dot         1192
# dtype: int64

# %%
print len(df_lower_al2)
order_col(df_lower_al2)
# Out:
# 8336
# f_denim      2223
# s_pencil     1688
# t_stripe     1684
# s_mini       1650
# t_floral     1627
# f_pleated    1558
# f_leather    1290
# f_knit       1240
# s_fit        1189
# s_midi        988
# p_zipper      930
# s_maxi        856
# f_cotton      818
# t_dot         496
# dtype: int64

# %%
print len(df_lower_al3)
order_col(df_lower_al3)
# Out:
# 1395
# s_pencil     472
# s_mini       463
# f_pleated    404
# t_floral     381
# f_leather    367
# s_midi       359
# t_stripe     350
# f_denim      287
# f_knit       285
# p_zipper     274
# s_fit        253
# s_maxi       188
# f_cotton     162
# t_dot        110
# dtype: int64

# %%
df2.head()
# Out:
#                                                  category upper_lower
# img/Sheer_Pleated-Front_Blouse/img_00000001.jpg         3           1
# img/Sheer_Pleated-Front_Blouse/img_00000002.jpg         3           1
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         3           1
# img/Sheer_Pleated-Front_Blouse/img_00000004.jpg         3           1
# img/Sheer_Pleated-Front_Blouse/img_00000005.jpg         3           1

# %%
#df_upper_al2_final = pd.merge(df_upper_al2, df2, left_index = True, right_index = True)

# %%
#df_lower_al2_final = pd.merge(df_lower_al2, df2, left_index = True, right_index = True)

# %%
df_upper_al3_final.head()
# Out:
#                                                  t_floral  t_stripe  t_dot  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         0         0      0
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg         0         0      0
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg         0         0      0
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg         0         0      0
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg         0         0      0
#
#                                                  f_lace  f_denim  f_chiffon  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg       0        0          0
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg       0        0          0
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg       0        0          0
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg       0        0          0
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg       0        0          0
#
#                                                  f_cotton  f_leather  f_fur  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         0          0      0
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg         0          0      0
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg         0          0      0
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg         0          0      0
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg         0          0      0
#
#                                                  p_sleeveless      ...        \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg             1      ...
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg             0      ...
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg             1      ...
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg             0      ...
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg             1      ...
#
#                                                  p_collar  p_pocket  p_v-neck  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         0         0         1
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg         0         0         0
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg         0         0         0
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg         1         0         1
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg         0         0         0
#
#                                                  p_button  p_hooded  p_zipper  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg         0         0         0
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg         0         0         0
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg         0         0         1
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg         0         0         0
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg         1         0         0
#
#                                                  category_x  upper_lower_x  \
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg           3              1
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg           3              1
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg           3              1
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg           3              1
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg           3              1
#
#                                                 category_y  upper_lower_y
# img/Sheer_Pleated-Front_Blouse/img_00000003.jpg          3              1
# img/Sheer_Pleated-Front_Blouse/img_00000015.jpg          3              1
# img/Sheer_Pleated-Front_Blouse/img_00000019.jpg          3              1
# img/Sheer_Pleated-Front_Blouse/img_00000023.jpg          3              1
# img/Sheer_Pleated-Front_Blouse/img_00000024.jpg          3              1
#
# [5 rows x 21 columns]

# %%
#df_upper_al2_final.to_csv('category-upper-all.txt', sep=':')
df_upper_al3.to_csv('category-upper-all.txt', sep=':')
df_lower_al2.to_csv('category-lower-all.txt', sep=':')

# %%
print len(df_upper_al2_final.columns)
print len(df_lower_al2_final.columns)
# Out:
# 19
# 16

# %%
print len(df_upper_al3_final.columns)
print len(df_lower_al3_final.columns)
# Out:
# 21
# 18

# %%
df_upper_al2_final.columns
# Out:
# Index([u't_floral', u't_stripe', u't_dot', u'f_lace', u'f_denim', u'f_chiffon',
#        u'f_cotton', u'f_leather', u'f_fur', u'p_sleeveless', u'p_long-sleeve',
#        u'p_collar', u'p_pocket', u'p_v-neck', u'p_button', u'p_hooded',
#        u'p_zipper', u'category', u'upper_lower'],
#       dtype='object')

# %%
df_upper_al3_final.columns
# Out:
# Index([u't_floral', u't_stripe', u't_dot', u'f_lace', u'f_denim', u'f_chiffon',
#        u'f_cotton', u'f_leather', u'f_fur', u'p_sleeveless', u'p_long-sleeve',
#        u'p_collar', u'p_pocket', u'p_v-neck', u'p_button', u'p_hooded',
#        u'p_zipper', u'category_x', u'upper_lower_x', u'category_y',
#        u'upper_lower_y'],
#       dtype='object')
